# %% [markdown]
# Importing Libraries for Data Analysis Using Python

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\nivas\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\nivas\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\nivas\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
covid_vaccination_df = pd.read_csv('https://covid.ourworldindata.org/data/vaccinations/vaccinations.csv')

# %%
covid_vaccination_df.head(10)
# Out:
#     location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
# 4  Argentina      ARG  2021-01-02                 NaN                NaN
# 5  Argentina      ARG  2021-01-03                 NaN                NaN
# 6  Argentina      ARG  2021-01-04             39599.0                NaN
# 7  Argentina      ARG  2021-01-05                 NaN                NaN
# 8  Argentina      ARG  2021-01-06                 NaN                NaN
# 9  Argentina      ARG  2021-01-07                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
covid_vaccination_df.tail(5)
# Out:
#      location  iso_code        date  total_vaccinations  people_vaccinated  \
# 1756    World  OWID_WRL  2021-01-23          64079440.0         37755782.0
# 1757    World  OWID_WRL  2021-01-24          66399654.0         39423848.0
# 1758    World  OWID_WRL  2021-01-25          69096648.0         41067697.0
# 1759    World  OWID_WRL  2021-01-26          71600987.0         42679850.0
# 1760    World  OWID_WRL  2021-01-27          82482104.0         44306994.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1756                5342294.0               2959008.0           3527890.0
# 1757                5752373.0               2320214.0           3732406.0
# 1758                6221797.0               2696994.0           3908121.0
# 1759                6774213.0               2504339.0           3549128.0
# 1760                7470330.0              10881117.0           4041081.0
#
# ...

# %%
plt.figure(figsize = (25,25))
sns.countplot(data = covid_vaccination_df, x='location')

# %%
covid_vaccination_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.181000e+03       9.180000e+02             4.650000e+02
# mean         1.731424e+06       1.513241e+06             2.979467e+05
# std          6.843269e+06       4.756015e+06             9.022902e+05
# min          0.000000e+00       0.000000e+00             2.000000e+00
# 25%          1.889700e+04       2.477300e+04             1.985000e+03
# 50%          9.777600e+04       1.179280e+05             9.403000e+03
# 75%          6.133050e+05       6.745580e+05             1.709850e+05
# max          8.248210e+07       4.430699e+07             7.470330e+06
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            9.620000e+02        1.682000e+03
# mean             1.448260e+05        9.029573e+04
# std              6.040174e+05        3.353570e+05
# min              0.000000e+00        1.000000e+00
# 25%              1.946500e+03        1.478250e+03
# ...

# %%
covid_vaccine_india_df = covid_vaccination_df[covid_vaccination_df.location == 'India']

# %%
covid_vaccine_india_df.head(10)
# Out:
#     location iso_code        date  total_vaccinations  people_vaccinated  \
# 731    India      IND  2021-01-15                 0.0                NaN
# 732    India      IND  2021-01-16            191181.0                NaN
# 733    India      IND  2021-01-17            224301.0                NaN
# 734    India      IND  2021-01-18            454049.0                NaN
# 735    India      IND  2021-01-19            674835.0                NaN
# 736    India      IND  2021-01-20            806484.0                NaN
# 737    India      IND  2021-01-21           1043534.0                NaN
# 738    India      IND  2021-01-22           1390592.0                NaN
# 739    India      IND  2021-01-23           1582201.0                NaN
# 740    India      IND  2021-01-24           1615504.0                NaN
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 731                      NaN                     NaN                 NaN
# ...

# %%
covid_vaccine_india_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 731 to 743
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             13 non-null     object
#  1   iso_code                             13 non-null     object
#  2   date                                 13 non-null     object
#  3   total_vaccinations                   13 non-null     float64
#  4   people_vaccinated                    0 non-null      float64
#  5   people_fully_vaccinated              0 non-null      float64
#  6   daily_vaccinations_raw               12 non-null     float64
#  7   daily_vaccinations                   12 non-null     float64
#  8   total_vaccinations_per_hundred       13 non-null     float64
#  9   people_vaccinated_per_hundred        0 non-null      float64
#  10  people_fully_vaccinated_per_hundred  0 non-null      float64
# ...

# %%
covid_vaccine_india_df
# Out:
#     location iso_code        date  total_vaccinations  people_vaccinated  \
# 731    India      IND  2021-01-15                 0.0                NaN
# 732    India      IND  2021-01-16            191181.0                NaN
# 733    India      IND  2021-01-17            224301.0                NaN
# 734    India      IND  2021-01-18            454049.0                NaN
# 735    India      IND  2021-01-19            674835.0                NaN
# 736    India      IND  2021-01-20            806484.0                NaN
# 737    India      IND  2021-01-21           1043534.0                NaN
# 738    India      IND  2021-01-22           1390592.0                NaN
# 739    India      IND  2021-01-23           1582201.0                NaN
# 740    India      IND  2021-01-24           1615504.0                NaN
# 741    India      IND  2021-01-25           2023809.0                NaN
# 742    India      IND  2021-01-26           2029480.0                NaN
# ...

# %%
covid_vaccination_df.isnull().sum()
# Out:
# location                                  0
# iso_code                                226
# date                                      0
# total_vaccinations                      580
# people_vaccinated                       843
# people_fully_vaccinated                1296
# daily_vaccinations_raw                  799
# daily_vaccinations                       79
# total_vaccinations_per_hundred          580
# people_vaccinated_per_hundred           843
# people_fully_vaccinated_per_hundred    1296
# daily_vaccinations_per_million           79
# dtype: int64

# %%
pd.to_datetime(covid_vaccination_df.date, format='%Y-%m-%d %H:%M:%S.%f')
# Out:
# 0      2020-12-29
# 1      2020-12-30
# 2      2020-12-31
# 3      2021-01-01
# 4      2021-01-02
#           ...
# 1756   2021-01-23
# 1757   2021-01-24
# 1758   2021-01-25
# 1759   2021-01-26
# 1760   2021-01-27
# Name: date, Length: 1761, dtype: datetime64[ns]

# %%
covid_vaccination_df.iso_code.nunique()
# Out:
# 59
